# %%
import pandas as pd

# %%
#데이터 프레임 만들기
df = pd.Series(['bye', 'hi', 10])
df
# Out:
# 0    bye
# 1     hi
# 2     10
# dtype: object

# %%
#인덱스에 값 설정 가능
df = pd.Series(['bye', 'hi', 10], index=['a','b','c'])
df
# Out:
# a    bye
# b     hi
# c     10
# dtype: object

# %%
#df 만들기{'index' :[' a',' b ']}
df_st = pd.DataFrame({'name' :['jun','hi'],
                     'b' : ['c','a'],
                     'age': [11,12],
                     'd':['bb','cc']})
df_st
# Out:
#   name  b  age   d
# 0  jun  c   11  bb
# 1   hi  a   12  cc

# %%
print(df_st)
# Out:
#   name  b  age   d
# 0  jun  c   11  bb
# 1   hi  a   12  cc

# %%
#인덱스:괄호 안
df_st['name']
# Out:
# 0    jun
# 1     hi
# Name: name, dtype: object

# %%
df_series=df_st['b']
type(df_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 시리즈에 사용하는 메서드
# -index
# -values
# -keys

# %%
#인덱스의 개념
print(df_st.index)
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
#속성 값의 개념
print(df_st.values)
# Out:
# [['jun' 'c' 11 'bb']
#  ['hi' 'a' 12 'cc']]

# %%
#컬럼의 개념
print(df_st.keys()[3])
# Out:
# d

# %%
#시리즈값 자체로 mean, min, max, std 메서드 사용 가능하다!
ages=df_st['age']
ages.min()
# Out:
# 11

# %% [raw]
# # 데이터 프레임을 가공시에 시리즈 형태로 사용!
# 시리즈 메서드
# append -2 개 이상 시리즈 연결
# describe 요약통계
# drop_duplicates 중복값이 없는 시리즈 반환
# equls 시리즈에 해당 값이 있는지 확인
# get_values 시리즈 값 구하기 (values와 동일)
# isin 시리즈에 포함된 값이 있는지 확인
# min, max, mean, median
# replace 특정 값을 가진 시리즈 값 교체
# sample 임의의 값을 반환
# sort_values 값을 정렬
# to_frame 시리즈를 데이터 프레임으로 변환

# %%
#describe
ages.describe()
# Out:
# count     2.000000
# mean     11.500000
# std       0.707107
# min      11.000000
# 25%      11.250000
# 50%      11.500000
# 75%      11.750000
# max      12.000000
# Name: age, dtype: float64

# %%
#sort_values
ages.sort_values()
# Out:
# 0    11
# 1    12
# Name: age, dtype: int64

# %%
mpg = pd.read_csv('mpg.csv')

# %% [markdown]
# 시리즈 자체에서 비교

# %%
ctys=mpg['cty']
ctys[ctys > ctys.median()]
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 5      18
#        ..
# 227    21
# 228    18
# 229    19
# 230    21
# 232    18
# Name: cty, Length: 102, dtype: int64

# %%
#브로드캐스팅
print(ctys + ctys)
# Out:
# 0      36
# 1      42
# 2      40
# 3      42
# 4      32
#        ..
# 229    38
# 230    42
# 231    32
# 232    36
# 233    34
# Name: cty, Length: 234, dtype: int64

# %%
mpg['cty']+100
# Out:
# 0      118
# 1      121
# 2      120
# 3      121
# 4      116
#       ...
# 229    119
# 230    121
# 231    116
# 232    118
# 233    117
# Name: cty, Length: 234, dtype: int64

# %%
mpg[mpg['cty'] < mpg['cty'].mean()]
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 4           audi                 a4    2.8  1999    6    auto(l5)   f   16
# 8           audi         a4 quattro    1.8  1999    4    auto(l5)   4   16
# 11          audi         a4 quattro    2.8  1999    6    auto(l5)   4   15
# 14          audi         a4 quattro    3.1  2008    6  manual(m6)   4   15
# 15          audi         a6 quattro    2.8  1999    6    auto(l5)   4   15
# ..           ...                ...    ...   ...  ...         ...  ..  ...
# 204       toyota  toyota tacoma 4wd    3.4  1999    6    auto(l4)   4   15
# 205       toyota  toyota tacoma 4wd    4.0  2008    6  manual(m6)   4   15
# 206       toyota  toyota tacoma 4wd    4.0  2008    6    auto(l5)   4   16
# 219   volkswagen              jetta    2.8  1999    6    auto(l4)   f   16
# 231   volkswagen             passat    2.8  1999    6    auto(l5)   f   16
#
#      hwy fl category
# 4     26  p  compact
# 8     25  p  compact
# ...

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg *2  #다 두번씩 나옴
# Out:
#              manufacturer         model  displ  year  cyl  \
# 0                audiaudi          a4a4    3.6  3998    8
# 1                audiaudi          a4a4    3.6  3998    8
# 2                audiaudi          a4a4    4.0  4016    8
# 3                audiaudi          a4a4    4.0  4016    8
# 4                audiaudi          a4a4    5.6  3998   12
# ..                    ...           ...    ...   ...  ...
# 229  volkswagenvolkswagen  passatpassat    4.0  4016    8
# 230  volkswagenvolkswagen  passatpassat    4.0  4016    8
# 231  volkswagenvolkswagen  passatpassat    5.6  3998   12
# 232  volkswagenvolkswagen  passatpassat    5.6  3998   12
# 233  volkswagenvolkswagen  passatpassat    7.2  4016   12
#
#                     trans drv  cty  hwy  fl        category
# 0        auto(l5)auto(l5)  ff   36   58  pp  compactcompact
# 1    manual(m5)manual(m5)  ff   42   58  pp  compactcompact
# 2    manual(m6)manual(m6)  ff   40   62  pp  compactcompact
# ...

# %%
#새로운 파생 변수 만들기
mpg['new'] = mpg['cty']-mpg['hwy']
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  new
# 0    compact  -11
# 1    compact   -8
# 2    compact  -11
# 3    compact   -9
# ...

# %% [raw]
# mpg.columns

# %% [markdown]
# 시각화

# %%
import seaborn as sns
df = sns.load_dataset('anscombe')
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
#matplotlib 라이브러리 모듈
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df_1=df[df['dataset']=='I']
plt.plot(df_1['x'],df_1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(df_1['x'],df_1['y'],'o')

# %%
df.dataset.value_counts()
# Out:
# I      11
# II     11
# III    11
# IV     11
# Name: dataset, dtype: int64

# %%
df_1=df[df['dataset']=='I']
df_2=df[df['dataset']=='II']
df_3=df[df['dataset']=='III']
df_4=df[df['dataset']=='IV']
df_4
# Out:
#    dataset     x      y
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
#4개의 값을 시각화 처리 하는 경우!
#그래프를 그리기 위한 격자 기본틀 만들기

fig = plt.figure()
axes1 =fig.add_subplot(2,2,1)
axes2 =fig.add_subplot(2,2,2)
axes3 =fig.add_subplot(2,2,3)
axes4 =fig.add_subplot(2,2,4)

axes1.plot(df_1['x'], df_1['y'], 'o')
axes2.plot(df_2['x'], df_2['y'], 'o')
axes3.plot(df_3['x'], df_3['y'], 'o')
axes4.plot(df_4['x'], df_4['y'], 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(df['x'],df['y'])

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total_bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total_bill')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

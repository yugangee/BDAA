# %%
import pandas as pd
df = pd.read_csv('재무재표샘플데이터.csv')
df
# Out:
#        기업    연도       부채비율     매출액증가율      영업이익증가율     당기순이익증가율 매출액_상태  \
# 0      3S  2013  70.612320        NaN          NaN          NaN   적자전환
# 1      3S  2014  60.288336 -11.687845   173.179128   114.728018   흑자지속
# 2      3S  2015  56.323967 -24.352916    38.894997    14.974005   흑자지속
# 3      3S  2016  59.923676   2.240210   453.409466   -64.511098   흑자지속
# 4      3S  2017  54.331315  10.359573   148.592592    61.341308   흑자지속
# ...    ..   ...        ...        ...          ...          ...    ...
# 19403  힘스  2016  45.998444        NaN          NaN          NaN    NaN
# 19404  힘스  2017  72.028464        NaN    57.915341    59.139944    NaN
# 19405  힘스  2018  80.625862        NaN  1014.435660  1285.956550    NaN
# 19406  힘스  2019  70.065289        NaN   122.184183   112.102500    NaN
# 19407  힘스  2020  85.556186        NaN    69.152237    50.930528    NaN
#
#       영업이익_상태 당기순이익_상태        ROA        ROE    현재_주가    미래_주가    배당금  \
# ...

# %%
#특정기업
kakao = df[df['기업']=='카카오']
kakao
# Out:
#         기업    연도       부채비율     매출액증가율     영업이익증가율    당기순이익증가율 매출액_상태 영업이익_상태  \
# 14931  카카오  2013  81.609707        NaN         NaN         NaN   흑자전환    흑자전환
# 14932  카카오  2014  88.988653  57.748298   62.674472   59.013387   흑자지속    흑자지속
# 14933  카카오  2015  81.088068  46.483211  -99.153952  -90.213891   흑자지속    흑자지속
# 14934  카카오  2016  66.884992        NaN   23.719590  -20.333996    NaN    흑자지속
# 14935  카카오  2017  70.288575        NaN   29.776643   47.675213    NaN    흑자지속
# 14936  카카오  2018  70.697001        NaN -126.706024 -687.305732    NaN    흑자지속
# 14937  카카오  2019  65.697032        NaN   64.722558  104.646890    NaN    흑자지속
# 14938  카카오  2020  62.136084        NaN   54.637771  297.234209    NaN    흑자지속
#
#       당기순이익_상태        ROA        ROE     현재_주가     미래_주가  배당금  PER
# 14931     흑자전환  28.271936        NaN   15635.0   22881.0  NaN  NaN
# 14932     흑자지속   5.412578  11.348031   22881.0   19911.0  NaN  NaN
# ...

# %%
kakao.부채비율.mean()
# Out:
# 73.423764065

# %%
kakao.매출액증가율.mean()
# Out:
# 52.115754295

# %%
kakao.영업이익증가율.mean()
# Out:
# 1.3815798171428557

# %%
kakao.현재_주가.mean()
# Out:
# 31727.75

# %%
kakao.현재_주가.max()
# Out:
# 100157.0

# %%
kakao.현재_주가.min()
# Out:
# 15635.0

# %%
kakao1 = kakao[['연도', '부채비율']]
kakao1
# Out:
#          연도       부채비율
# 14931  2013  81.609707
# 14932  2014  88.988653
# 14933  2015  81.088068
# 14934  2016  66.884992
# 14935  2017  70.288575
# 14936  2018  70.697001
# 14937  2019  65.697032
# 14938  2020  62.136084

# %%
kakao2 = kakao[['연도', '매출액증가율', '영업이익증가율', '당기순이익증가율']]
kakao2
# Out:
#          연도     매출액증가율     영업이익증가율    당기순이익증가율
# 14931  2013        NaN         NaN         NaN
# 14932  2014  57.748298   62.674472   59.013387
# 14933  2015  46.483211  -99.153952  -90.213891
# 14934  2016        NaN   23.719590  -20.333996
# 14935  2017        NaN   29.776643   47.675213
# 14936  2018        NaN -126.706024 -687.305732
# 14937  2019        NaN   64.722558  104.646890
# 14938  2020        NaN   54.637771  297.234209

# %%
kakao3 = kakao[['연도', '매출액_상태', '영업이익_상태', '당기순이익_상태']]
kakao3
# Out:
#          연도 매출액_상태 영업이익_상태 당기순이익_상태
# 14931  2013   흑자전환    흑자전환     흑자전환
# 14932  2014   흑자지속    흑자지속     흑자지속
# 14933  2015   흑자지속    흑자지속     흑자지속
# 14934  2016    NaN    흑자지속     흑자지속
# 14935  2017    NaN    흑자지속     흑자지속
# 14936  2018    NaN    흑자지속     흑자지속
# 14937  2019    NaN    흑자지속     적자전환
# 14938  2020    NaN    흑자지속     흑자전환

# %%
kakao4 = kakao[['연도', 'ROA', 'ROE', 'PER']]
kakao4
# Out:
#          연도        ROA        ROE  PER
# 14931  2013  28.271936        NaN  NaN
# 14932  2014   5.412578  11.348031  NaN
# 14933  2015   2.470293   3.120198  NaN
# 14934  2016   1.193540   2.093383  NaN
# 14935  2017   1.970160   3.076972  NaN
# 14936  2018   0.199620   0.314940  NaN
# 14937  2019  -3.913409  -6.015946  NaN
# 14938  2020   1.450227   2.633075  NaN

# %%
kakao5 = kakao[['연도', '현재_주가', '미래_주가']]
kakao5
# Out:
#          연도     현재_주가     미래_주가
# 14931  2013   15635.0   22881.0
# 14932  2014   22881.0   19911.0
# 14933  2015   19911.0   17462.0
# 14934  2016   17462.0   25892.0
# 14935  2017   25892.0   20673.0
# 14936  2018   20673.0   31211.0
# 14937  2019   31211.0  100157.0
# 14938  2020  100157.0       NaN

# %%
from matplotlib import pyplot as plt

# %%
#막대그래프
plt.bar(kakao1['연도'], kakao1['부채비율'])
plt.xlabel('연도')
plt.ylabel('부채비율')
# Out:
# Text(0, 0.5, '부채비율')

# %%
import matplotlib

matplotlib.rcParams['font.family'] ='Malgun Gothic'

matplotlib.rcParams['axes.unicode_minus'] =False

# %%
plt.plot(kakao1['연도'], kakao1['부채비율'])
plt.xlabel('연도')
plt.ylabel('부채비율')
# Out:
# Text(0, 0.5, '부채비율')

# %%
plt.plot(kakao2['연도'],kakao2['영업이익증가율'],label='영업이익증가율')
plt.plot(kakao2['연도'],kakao2['당기순이익증가율'],label='당기순이익증가율')
plt.xlabel('연도')
plt.legend(loc='upper left')

#https://www.ilovepc.co.kr/news/articleView.html?idxno=21587
#카카오가 지난해 큰 매출 성장을 이뤘음에도 마케팅 비용 증가와 연말 상여금 지급 등으로 영업이익과 당기순이익이 전년 대비 크게 하락했다.

# %%
plt.plot(kakao4['연도'],kakao4['ROA'],label='ROA(총자산순이익률)')
plt.plot(kakao4['연도'],kakao4['ROE'],label='ROE(자기자본이익률)')
plt.xlabel('연도')
plt.legend(loc='upper right')

# %%
plt.plot(kakao5['연도'],kakao5['현재_주가'],label='현재_주가')
plt.plot(kakao5['연도'],kakao5['미래_주가'],label='미래_주가')
plt.xlabel('연도')
plt.legend(loc='upper right')

# %%
df2 = pd.read_csv('주가리포트_샘플.csv')
df2
# Out:
#          종목명                        리포트제목     적정가격      의견       증권사  \
# 0     SK하이닉스            리스크 관리가 좀더 필요한 시점   120000  매수(유지)    하이투자증권
# 1        솔루엠                    수주잔고가 쌓인다    28000  매수(유지)    하이투자증권
# 2       유한양행        높아진 성공 가능성 할인보다 할증 요소    90000  매수(유지)      키움증권
# 3     코스모신소재                   증설은 곧 성장이다        -       -      키움증권
# 4        넷마블   올해까지 실적으론 고평가, 내년 실적부턴 저평가   145000      매수  이베스트투자증권
# ...      ...                          ...      ...     ...       ...
# 1572  우리금융지주   경상 수익성을 레벨업 시킨 top-line 개선    12500      매수    하나금융투자
# 1573   엔씨소프트     1Q21 Preview, 리니지M, 블소2   1200000  매수(유지)     유안타증권
# 1574   NAVER  1Q21 Preview, 쿠팡, LINE, 제페토   550000  매수(유지)     유안타증권
# 1575     카카오  1Q21 preview, 카카오 모빌리티, 두나무   135000  매수(유지)     유안타증권
# 1576  코스모신소재      양극재와 MLCC용 필름 동반 호조 사이클        -       -      키움증권
#
#               날짜
# 0     2021.10.15
# 1     2021.10.15
# 2     2021.10.15
# 3     2021.10.15
# 4     2021.10.15
# ...          ...
# ...

# %%
df2['종목명']
# Out:
# 0       SK하이닉스
# 1          솔루엠
# 2         유한양행
# 3       코스모신소재
# 4          넷마블
#          ...
# 1572    우리금융지주
# 1573     엔씨소프트
# 1574     NAVER
# 1575       카카오
# 1576    코스모신소재
# Name: 종목명, Length: 1577, dtype: object

# %%
df2.loc[df_2['의견'].str.contains('매수')]
# Out:
#          종목명                        리포트제목     적정가격      의견       증권사  \
# 0     SK하이닉스            리스크 관리가 좀더 필요한 시점   120000  매수(유지)    하이투자증권
# 1        솔루엠                    수주잔고가 쌓인다    28000  매수(유지)    하이투자증권
# 2       유한양행        높아진 성공 가능성 할인보다 할증 요소    90000  매수(유지)      키움증권
# 4        넷마블   올해까지 실적으론 고평가, 내년 실적부턴 저평가   145000      매수  이베스트투자증권
# 5       현대해상          보험손익 개선이 호실적을 지속 견인    35000  매수(유지)  이베스트투자증권
# ...      ...                          ...      ...     ...       ...
# 1571     F&F           MLB, 중국인의 마음을 저격하다   200000      매수    하나금융투자
# 1572  우리금융지주   경상 수익성을 레벨업 시킨 top-line 개선    12500      매수    하나금융투자
# 1573   엔씨소프트     1Q21 Preview, 리니지M, 블소2   1200000  매수(유지)     유안타증권
# 1574   NAVER  1Q21 Preview, 쿠팡, LINE, 제페토   550000  매수(유지)     유안타증권
# 1575     카카오  1Q21 preview, 카카오 모빌리티, 두나무   135000  매수(유지)     유안타증권
#
#               날짜
# 0     2021.10.15
# 1     2021.10.15
# 2     2021.10.15
# 4     2021.10.15
# 5     2021.10.15
# ...          ...
# ...

# %%
df2.loc[df_2['증권사'].str.contains('키움증권')]
# Out:
#               종목명                    리포트제목    적정가격          의견   증권사  \
# 2            유한양행    높아진 성공 가능성 할인보다 할증 요소   90000      매수(유지)  키움증권
# 3          코스모신소재               증설은 곧 성장이다       -           -  키움증권
# 6            강원랜드          위드 코로나 수혜의 대표주자   38000      매수(유지)  키움증권
# 7             GKL            실적 최저점을 지나는 중   20500      매수(유지)  키움증권
# 47           유한양행    높아진 성공 가능성 할인보다 할증 요소   90000      매수(유지)  키움증권
# ...           ...                      ...     ...         ...   ...
# 1545           기아       제품 수요에 기반한 무한한 자신감  120000      매수(유지)  키움증권
# 1546  LS ELECTRIC               한걸음 늦은 출발    85000      매수(유지)  키움증권
# 1547         KB금융  실적 개선보다는 배당 여력 개선에 주목해야   78000      매수(유지)  키움증권
# 1548      솔루스첨단소재                  건강한 성장통   56000  OutPerform  키움증권
# 1576       코스모신소재  양극재와 MLCC용 필름 동반 호조 사이클       -           -  키움증권
#
#               날짜
# 2     2021.10.15
# 3     2021.10.15
# 6     2021.10.15
# 7     2021.10.15
# 47    2021.10.14
# ...          ...
# ...

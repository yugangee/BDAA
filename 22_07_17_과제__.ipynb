# %%
import pandas as pd

# %%
import numpy as np

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.assign(mpg = np.where(mpg['year']>=2005,'recent','old'))
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category     mpg
# 0    compact     old
# 1    compact     old
# 2    compact  recent
# ...

# %%
mpg.groupby('manufacturer').agg(mean_displ = ('displ', 'mean'))
# Out:
#               mean_displ
# manufacturer
# audi            2.544444
# chevrolet       5.063158
# dodge           4.378378
# ford            4.536000
# honda           1.711111
# hyundai         2.428571
# jeep            4.575000
# land rover      4.300000
# lincoln         5.400000
# mercury         4.400000
# nissan          3.269231
# pontiac         3.960000
# subaru          2.457143
# toyota          2.952941
# volkswagen      2.255556

# %%
mpg.groupby('trans').agg(mean_displ = ('displ', 'mean'))
# Out:
#             mean_displ
# trans
# auto(av)      2.920000
# auto(l3)      2.100000
# auto(l4)      3.715663
# auto(l5)      3.917949
# auto(l6)      4.633333
# auto(s4)      3.433333
# auto(s5)      3.766667
# auto(s6)      3.412500
# manual(m5)    2.732759
# manual(m6)    3.678947

# %%
mpg.groupby('manufacturer').mean()
# Out:
#                  displ         year       cyl        cty        hwy
# manufacturer
# audi          2.544444  2003.500000  5.222222  17.611111  26.444444
# chevrolet     5.063158  2004.684211  7.263158  15.000000  21.894737
# dodge         4.378378  2004.108108  7.081081  13.135135  17.945946
# ford          4.536000  2002.600000  7.200000  14.000000  19.360000
# honda         1.711111  2003.000000  4.000000  24.444444  32.555556
# hyundai       2.428571  2004.142857  4.857143  18.642857  26.857143
# jeep          4.575000  2005.750000  7.250000  13.500000  17.625000
# land rover    4.300000  2003.500000  8.000000  11.500000  16.500000
# lincoln       5.400000  2002.000000  8.000000  11.333333  17.000000
# mercury       4.400000  2003.500000  7.000000  13.250000  18.000000
# nissan        3.269231  2003.846154  5.538462  18.076923  24.615385
# pontiac       3.960000  2002.600000  6.400000  17.000000  26.400000
# subaru        2.457143  2004.142857  4.000000  19.285714  25.571429
# ...

# %%
mpg.groupby(['manufacturer','model']).agg(mean_cty =('cty','mean'))
# Out:
#                                       mean_cty
# manufacturer model
# audi         a4                      18.857143
#              a4 quattro              17.125000
#              a6 quattro              16.000000
# chevrolet    c1500 suburban 2wd      12.800000
#              corvette                15.400000
#              k1500 tahoe 4wd         12.500000
#              malibu                  18.800000
# dodge        caravan 2wd             15.818182
#              dakota pickup 4wd       12.777778
#              durango 4wd             11.857143
#              ram 1500 pickup 4wd     11.400000
# ford         expedition 2wd          11.333333
#              explorer 4wd            13.666667
#              f150 pickup 4wd         13.000000
#              mustang                 15.888889
# honda        civic                   24.444444
# hyundai      sonata                  19.000000
#              tiburon                 18.285714
# ...

# %%
mpg.query('manufacturer=="ford"').groupby(['drv']).agg(n =('drv','count'))
# Out:
#       n
# drv
# 4    13
# r    12

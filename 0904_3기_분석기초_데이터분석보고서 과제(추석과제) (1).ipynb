# %%
import pandas as pd

# %%
df = pd.read_csv('재무재표샘플데이터.csv')

# %%
df
# Out:
#        기업    연도       부채비율     매출액증가율      영업이익증가율     당기순이익증가율 매출액_상태  \
# 0      3S  2013  70.612320        NaN          NaN          NaN   적자전환
# 1      3S  2014  60.288336 -11.687845   173.179128   114.728018   흑자지속
# 2      3S  2015  56.323967 -24.352916    38.894997    14.974005   흑자지속
# 3      3S  2016  59.923676   2.240210   453.409466   -64.511098   흑자지속
# 4      3S  2017  54.331315  10.359573   148.592592    61.341308   흑자지속
# ...    ..   ...        ...        ...          ...          ...    ...
# 19403  힘스  2016  45.998444        NaN          NaN          NaN    NaN
# 19404  힘스  2017  72.028464        NaN    57.915341    59.139944    NaN
# 19405  힘스  2018  80.625862        NaN  1014.435660  1285.956550    NaN
# 19406  힘스  2019  70.065289        NaN   122.184183   112.102500    NaN
# 19407  힘스  2020  85.556186        NaN    69.152237    50.930528    NaN
#
#       영업이익_상태 당기순이익_상태        ROA        ROE    현재_주가    미래_주가    배당금  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=19408, step=1)

# %%
df.columns
# Out:
# Index(['기업', '연도', '부채비율', '매출액증가율', '영업이익증가율', '당기순이익증가율', '매출액_상태',
#        '영업이익_상태', '당기순이익_상태', 'ROA', 'ROE', '현재_주가', '미래_주가', '배당금', 'PER'],
#       dtype='object')

# %%
df.기업.value_counts()
# Out:
# 홈캐스트           9
# 아이톡시           9
# 웹케시            9
# 프레스티지바이오로직스    9
# 스타플렉스          9
#               ..
# 나이벡            8
# 삼화전자           8
# 남해화학           8
# 한송네오텍          8
# 케이엠제약          8
# Name: 기업, Length: 2352, dtype: int64

# %%
df['기업'].drop_duplicates().to_frame() #중복을 제거한 실제 기업 수
# Out:
#            기업
# 0          3S
# 8      AJ네트웍스
# 17      AK홀딩스
# 25     APS홀딩스
# 33      AP시스템
# ...       ...
# 19367  흥국에프엔비
# 19375    흥국화재
# 19383    흥아해운
# 19392      희림
# 19400      힘스
#
# [2352 rows x 1 columns]

# %% [markdown]
# ## 연도별 기업 부채증가비율, 영업이익증가비율, 당기순이익증가비율

# %%
df.isna().sum()
# Out:
# 기업             0
# 연도             0
# 부채비율        3833
# 매출액증가율      6132
# 영업이익증가율     5922
# 당기순이익증가율    6025
# 매출액_상태      4494
# 영업이익_상태     4299
# 당기순이익_상태    4408
# ROA         3941
# ROE         6017
# 현재_주가       1472
# 미래_주가       3650
# 배당금         5608
# PER         6414
# dtype: int64

# %%
df['부채비율>50']=df['부채비율'] >50

# %%
df['부채비율>50'].value_counts()
# Out:
# True     9731
# False    9677
# Name: 부채비율>50, dtype: int64

# %%
df['부채비율>50'].value_counts(normalize=True)
# Out:
# True     0.501391
# False    0.498609
# Name: 부채비율>50, dtype: float64

# %%
df['부채비율>50'].value_counts(normalize=True).plot(kind='bar')

# %%
df['매출액_상태'].value_counts()
# Out:
# 흑자지속    14609
# 흑자전환      151
# 적자지속       80
# 적자전환       74
# Name: 매출액_상태, dtype: int64

# %%
df['부채비율>50'].value_counts(normalize=True).plot(kind='pie')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df
# Out:
#        기업    연도       부채비율     매출액증가율      영업이익증가율     당기순이익증가율 매출액_상태  \
# 0      3S  2013  70.612320        NaN          NaN          NaN   적자전환
# 1      3S  2014  60.288336 -11.687845   173.179128   114.728018   흑자지속
# 2      3S  2015  56.323967 -24.352916    38.894997    14.974005   흑자지속
# 3      3S  2016  59.923676   2.240210   453.409466   -64.511098   흑자지속
# 4      3S  2017  54.331315  10.359573   148.592592    61.341308   흑자지속
# ...    ..   ...        ...        ...          ...          ...    ...
# 19403  힘스  2016  45.998444        NaN          NaN          NaN    NaN
# 19404  힘스  2017  72.028464        NaN    57.915341    59.139944    NaN
# 19405  힘스  2018  80.625862        NaN  1014.435660  1285.956550    NaN
# 19406  힘스  2019  70.065289        NaN   122.184183   112.102500    NaN
# 19407  힘스  2020  85.556186        NaN    69.152237    50.930528    NaN
#
#       영업이익_상태 당기순이익_상태        ROA        ROE    현재_주가    미래_주가    배당금  \
# ...

# %%
#groupby를 이용해서 
df.groupby('기업')['현재_주가'].max()
# Out:
# 기업
# 3S         6100.0
# AJ네트웍스     8300.0
# AK홀딩스     98500.0
# APS홀딩스    20750.0
# AP시스템     41700.0
#            ...
# 흥국에프엔비    10406.0
# 흥국화재       5900.0
# 흥아해운      40284.0
# 희림         6230.0
# 힘스        16530.0
# Name: 현재_주가, Length: 2352, dtype: float64

# %%
df.groupby(['기업','연도','부채비율>50'])['ROE'].max()
# Out:
# 기업  연도    부채비율>50
# 3S  2013  True             NaN
#     2014  True      -10.489496
#     2015  True      -13.836280
#     2016  True       -9.383155
#     2017  True      -27.605322
#                        ...
# 힘스  2016  False            NaN
#     2017  True       32.533952
#     2018  True       -1.950691
#     2019  True       14.897331
#     2020  True       24.841243
# Name: ROE, Length: 18908, dtype: float64

# %%
import numpy as np

# %%
df.groupby('기업',as_index=False)[['연도','부채비율','매출액증가율']].agg({'부채비율':['max','min'],
                                                       '매출액증가율':[np.mean]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df.groupby('기업',as_index=False)[['연도','부채비율','매출액증가율']].agg({'부채비율':['max','min'],
#       2                                                        '매출액증가율':[np.mean]})
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#        기업    연도       부채비율     매출액증가율      영업이익증가율     당기순이익증가율 매출액_상태  \
# 0      3S  2013  70.612320        NaN          NaN          NaN   적자전환
# 1      3S  2014  60.288336 -11.687845   173.179128   114.728018   흑자지속
# 2      3S  2015  56.323967 -24.352916    38.894997    14.974005   흑자지속
# 3      3S  2016  59.923676   2.240210   453.409466   -64.511098   흑자지속
# 4      3S  2017  54.331315  10.359573   148.592592    61.341308   흑자지속
# ...    ..   ...        ...        ...          ...          ...    ...
# 19403  힘스  2016  45.998444        NaN          NaN          NaN    NaN
# 19404  힘스  2017  72.028464        NaN    57.915341    59.139944    NaN
# 19405  힘스  2018  80.625862        NaN  1014.435660  1285.956550    NaN
# 19406  힘스  2019  70.065289        NaN   122.184183   112.102500    NaN
# 19407  힘스  2020  85.556186        NaN    69.152237    50.930528    NaN
#
#       영업이익_상태 당기순이익_상태        ROA        ROE    현재_주가    미래_주가    배당금  \
# ...

# %%
df.isna().sum()
# Out:
# 기업             0
# 연도             0
# 부채비율        3833
# 매출액증가율      6132
# 영업이익증가율     5922
# 당기순이익증가율    6025
# 매출액_상태      4494
# 영업이익_상태     4299
# 당기순이익_상태    4408
# ROA         3941
# ROE         6017
# 현재_주가       1472
# 미래_주가       3650
# 배당금         5608
# PER         6414
# 부채비율>50        0
# dtype: int64

# %%
df[df['기업']=='삼성전자']
# Out:
#         기업    연도       부채비율     매출액증가율     영업이익증가율    당기순이익증가율 매출액_상태 영업이익_상태  \
# 6966  삼성전자  2013  70.076374        NaN         NaN         NaN   흑자지속    흑자지속
# 6967  삼성전자  2014  72.947674 -10.904960  -46.992642  -30.265443   흑자지속    흑자지속
# 6968  삼성전자  2015  73.936807  -2.767211    5.256305  -22.739671   흑자지속    흑자지속
# 6969  삼성전자  2016  73.601042   0.601022    9.668827   16.131009   흑자지속    흑자지속
# 6970  삼성전자  2017  71.082002  15.739777   45.492308   46.129783   흑자지속    흑자지속
# 6971  삼성전자  2018  73.006597   1.721301    8.901218    4.866652   흑자지속    흑자지속
# 6972  삼성전자  2019  74.562363  -5.803161 -112.062769 -103.988833   흑자지속    흑자지속
# 6973  삼성전자  2020  72.956625   2.705202   22.852129   17.680236   흑자지속    흑자지속
#
#      당기순이익_상태        ROA        ROE    현재_주가    미래_주가      배당금        PER  \
# 6966     흑자지속  14.235554        NaN  26780.0  28460.0  14300.0   0.135361
# 6967     흑자지속  10.152790  14.708613  28460.0  26240.0  20000.0   0.185886
# ...

# %%
df_3s= df[df['기업']=='3S']

# %%
df_3s
# Out:
#    기업    연도       부채비율     매출액증가율     영업이익증가율    당기순이익증가율 매출액_상태 영업이익_상태  \
# 0  3S  2013  70.612320        NaN         NaN         NaN   적자전환    적자전환
# 1  3S  2014  60.288336 -11.687845  173.179128  114.728018   흑자지속    적자전환
# 2  3S  2015  56.323967 -24.352916   38.894997   14.974005   흑자지속    적자지속
# 3  3S  2016  59.923676   2.240210  453.409466  -64.511098   흑자지속    흑자전환
# 4  3S  2017  54.331315  10.359573  148.592592   61.341308   흑자지속    적자전환
# 5  3S  2018  62.099593  16.039609  826.416965 -514.688284   흑자지속    흑자전환
# 6  3S  2019  64.451874  11.763751   79.946967  201.499468   흑자지속    흑자지속
# 7  3S  2020  67.189115 -58.250334 -255.781887  230.612320   흑자지속    흑자지속
#
#   당기순이익_상태        ROA        ROE   현재_주가   미래_주가  배당금         PER  부채비율>50
# 0     적자전환   1.036271        NaN  6100.0  4350.0  NaN         NaN     True
# 1     적자전환  -6.675781 -10.489496  4350.0  2535.0  NaN         NaN     True
# 2     적자지속  -8.312107 -13.836280  2535.0  3595.0  NaN         NaN     True
# ...

# %%
df_3s.부채비율.mean()
# Out:
# 61.902524445

# %%
df_3s
# Out:
#    기업    연도       부채비율     매출액증가율     영업이익증가율    당기순이익증가율 매출액_상태 영업이익_상태  \
# 0  3S  2013  70.612320        NaN         NaN         NaN   적자전환    적자전환
# 1  3S  2014  60.288336 -11.687845  173.179128  114.728018   흑자지속    적자전환
# 2  3S  2015  56.323967 -24.352916   38.894997   14.974005   흑자지속    적자지속
# 3  3S  2016  59.923676   2.240210  453.409466  -64.511098   흑자지속    흑자전환
# 4  3S  2017  54.331315  10.359573  148.592592   61.341308   흑자지속    적자전환
# 5  3S  2018  62.099593  16.039609  826.416965 -514.688284   흑자지속    흑자전환
# 6  3S  2019  64.451874  11.763751   79.946967  201.499468   흑자지속    흑자지속
# 7  3S  2020  67.189115 -58.250334 -255.781887  230.612320   흑자지속    흑자지속
#
#   당기순이익_상태        ROA        ROE   현재_주가   미래_주가  배당금         PER  부채비율>50
# 0     적자전환   1.036271        NaN  6100.0  4350.0  NaN         NaN     True
# 1     적자전환  -6.675781 -10.489496  4350.0  2535.0  NaN         NaN     True
# 2     적자지속  -8.312107 -13.836280  2535.0  3595.0  NaN         NaN     True
# ...

# %% [markdown]
# ### 추가 분석 진행 설명
# - 연도, 기업에 컬럼을 이용해서 merge
#
# - 외부데이터, 통계청, 다트 외부에서 다운로드 가능한 데이터를 기반으로 추가 분석진행도 가능하다.

# %%
df_2 = pd.read_csv('주가리포트_샘플.csv')

# %%
df_2['종목명']
# Out:
# 0       SK하이닉스
# 1          솔루엠
# 2         유한양행
# 3       코스모신소재
# 4          넷마블
#          ...
# 1572    우리금융지주
# 1573     엔씨소프트
# 1574     NAVER
# 1575       카카오
# 1576    코스모신소재
# Name: 종목명, Length: 1577, dtype: object

# %%
df['기업']
# Out:
# 0        3S
# 1        3S
# 2        3S
# 3        3S
# 4        3S
#          ..
# 19403    힘스
# 19404    힘스
# 19405    힘스
# 19406    힘스
# 19407    힘스
# Name: 기업, Length: 19408, dtype: object

# %%
df_2['의견'].str.contains('매수')
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1572     True
# 1573     True
# 1574     True
# 1575     True
# 1576    False
# Name: 의견, Length: 1577, dtype: bool

# %%
df_2.loc[df_2['의견'].str.contains('매수')]
# Out:
#          종목명                        리포트제목     적정가격      의견       증권사  \
# 0     SK하이닉스            리스크 관리가 좀더 필요한 시점   120000  매수(유지)    하이투자증권
# 1        솔루엠                    수주잔고가 쌓인다    28000  매수(유지)    하이투자증권
# 2       유한양행        높아진 성공 가능성 할인보다 할증 요소    90000  매수(유지)      키움증권
# 4        넷마블   올해까지 실적으론 고평가, 내년 실적부턴 저평가   145000      매수  이베스트투자증권
# 5       현대해상          보험손익 개선이 호실적을 지속 견인    35000  매수(유지)  이베스트투자증권
# ...      ...                          ...      ...     ...       ...
# 1571     F&F           MLB, 중국인의 마음을 저격하다   200000      매수    하나금융투자
# 1572  우리금융지주   경상 수익성을 레벨업 시킨 top-line 개선    12500      매수    하나금융투자
# 1573   엔씨소프트     1Q21 Preview, 리니지M, 블소2   1200000  매수(유지)     유안타증권
# 1574   NAVER  1Q21 Preview, 쿠팡, LINE, 제페토   550000  매수(유지)     유안타증권
# 1575     카카오  1Q21 preview, 카카오 모빌리티, 두나무   135000  매수(유지)     유안타증권
#
#               날짜
# 0     2021.10.15
# 1     2021.10.15
# 2     2021.10.15
# 4     2021.10.15
# 5     2021.10.15
# ...          ...
# ...

# %%
df_2.loc[df_2['의견'].str.contains('유지')]
# Out:
#           종목명                        리포트제목     적정가격      의견       증권사  \
# 0      SK하이닉스            리스크 관리가 좀더 필요한 시점   120000  매수(유지)    하이투자증권
# 1         솔루엠                    수주잔고가 쌓인다    28000  매수(유지)    하이투자증권
# 2        유한양행        높아진 성공 가능성 할인보다 할증 요소    90000  매수(유지)      키움증권
# 5        현대해상          보험손익 개선이 호실적을 지속 견인    35000  매수(유지)  이베스트투자증권
# 6        강원랜드              위드 코로나 수혜의 대표주자    38000  매수(유지)      키움증권
# ...       ...                          ...      ...     ...       ...
# 1563    SK텔레콤         실적 성장과 기업 분할의 시너지 효과   390000  매수(유지)    한화투자증권
# 1564  에이테크솔루션         실적 성장과 기업 분할의 시너지 효과   390000  매수(유지)    한화투자증권
# 1573    엔씨소프트     1Q21 Preview, 리니지M, 블소2   1200000  매수(유지)     유안타증권
# 1574    NAVER  1Q21 Preview, 쿠팡, LINE, 제페토   550000  매수(유지)     유안타증권
# 1575      카카오  1Q21 preview, 카카오 모빌리티, 두나무   135000  매수(유지)     유안타증권
#
#               날짜
# 0     2021.10.15
# 1     2021.10.15
# 2     2021.10.15
# 5     2021.10.15
# 6     2021.10.15
# ...

# %% [markdown]
# ### 필수 과제 정리
#
# - 데이터 분석 보고서 과제
# - 추석 이후 과제 발표 진행
# - 재무제표 데이터 & 주가리포트 데이터 (추가 외부 데이터 병합 환영)를 가지고 분석 보고서 작성
# - 본인이 원하는 기업을 선정해서 해당 컬럼에 대한 내용을 시각화 정리하고 주석 처리로 인사이트를 도출해 주세요!
# - 해당 연도, 해당기업에 기사를 리서치해서 왜 그런지에 대한 이유를 같이 정리해 주세요!
#
# - 필수는 제공된 컬럼에 대해서 모든 인사이트를 만들어 주세요!
# - 추가 파생변수도 만들어서 진행 가능합니다. (재무비율 분석)
# - 논문에 나와 있는 내용들을 진행해도 가능 ( 퀀트투자 관련해서 분석 진행해도 좋습니다!)
